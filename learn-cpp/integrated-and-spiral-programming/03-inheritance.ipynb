// %% [markdown]
// # Inheritance
//
// Inheritance allows a class to inherit properties and methods from another class.
//
// ### Key concepts
// - **Base class** (parent) - class being inherited from
// - **Derived class** (child) - class that inherits
// - **public inheritance** - public members remain public
//
// ### Syntax
//
// ```cpp
// class Derived : public Base {
//     // additional members
// };
// ```

// %%
#include <iostream>
using namespace std;

class Point;
ostream& operator<<(ostream& out, const Point& c);

template<typename T>
void Swap(T &a, T &b) { 
    T temp = a; 
    a = b; 
    b = temp; 
}

class Point {
public:
    int x, y;
    
    Point(int c1, int c2) : x(c1), y(c2) {}
    
    Point& operator=(Point rhs) {
        x = rhs.x; 
        y = rhs.y;
        return *this;
    }
};

// Complex inherits from Point
class Complex : public Point {
private:
    int &real, &imag;
    
public:
    Complex(int r, int i) : Point(r, i), real(x), imag(y) {
        cout << "Forming..." << *this;
    }
};

ostream& operator<<(ostream& out, const Point& c) {
    out << "x:" << c.x << " ";
    out << "y:" << c.y << "\n";
    return out;
}

Complex c1(15, 15), c2(100, 100);
// Out:
// input_line_8:5:1: error: expected expression
// template<typename T>
// ^:5:1: error: expected expression
// template<typename T>
// ^
// input_line_8:24:24: error: base class has incomplete type
// class Complex : public Point {
//                 ~~~~~~~^~~~~
// input_line_8:3:7: note: forward declaration of 'Point'
// class Point;
//       ^
// input_line_8:29:29: error: type 'Point' is not a direct or virtual base of 'Complex'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                             ^~~~~
//
// input_line_8:24:24: error: base class has incomplete type
// class Complex : public Point {
//                 ~~~~~~~^~~~~
// input_line_8:3:7: note: forward declaration of 'Point'
// class Point;
//       ^
// input_line_8:29:29: error: type 'Point' is not a direct or virtual base of 'Complex'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                             ^~~~~
// input_line_8:29:47: error: use of undeclared identifier 'x'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                                               ^
// input_line_8:29:47: error: use of undeclared identifier 'x'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                                               ^
// input_line_8:29:56: error: use of undeclared identifier 'y'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                                                        ^
// input_line_8:30:30: input_line_8:29:56: error: use of undeclared identifier 'y'
//     Complex(int r, int i) : Point(r, i), real(x), imag(y) {
//                                                        ^
// input_line_8:30:30: error: invalid operands to binary expression ('basic_ostream<char, std::char_traits<char> >' and 'Complex')
//         cout << "Forming..." << *this;
//         ~~~~~~~~~~~~~~~~~~~~ ^  ~~~~~
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:292:7: note: candidate function not viable: no known conversion from 'Complex' to 'const void *' for 1st argument; remove *
//       operator<<(const void* __p)
//       ^error: invalid operands to binary expression ('basic_ostream<char, std::char_traits<char> >' and 'Complex')
//         cout << "Forming..." << *this;
//         ~~~~~~~~~~~~~~~~~~~~ ^  ~~~~~
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:292:7: note: candidate function not viable: no known conversion from 'Complex' to 'const void *' for 1st argument; remove *
//       operator<<(const void* __p)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/cstddef:124:5: note: candidate function template not viable: no known conversion from 'basic_ostream<char, std::char_traits<char> >' to 'std::byte' for 1st argument
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
//
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/cstddef:124:5: note: candidate function template not viable: no known conversion from 'basic_ostream<char, std::char_traits<char> >' to 'std::byte' for 1st argument
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/system_error:339:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:110:7:/opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/system_error:339:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:110:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__ostream_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ostream_type &)' (aka 'basic_ostream<char, std::char_traits<char> > &(*)(basic_ostream<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ostream_type& (*__pf)(__ostream_type&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:119:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//  note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__ostream_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ostream_type &)' (aka 'basic_ostream<char, std::char_traits<char> > &(*)(basic_ostream<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ostream_type& (*__pf)(__ostream_type&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:119:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:129:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream      operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:129:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:168:7: note: candidate function not viable: no known conversion from 'Complex' to 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:172:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:176:7: note: candidate function not viable: no known conversion from 'Complex' to 'bool' for 1st argument
//       operator<<(bool __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:180:7: note: candidate function not viable: no known conversion from 'Complex' to 'short' for 1st argument
// :168:7: note: candidate function not viable: no known conversion from 'Complex' to 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:172:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:176:7: note: candidate function not viable: no known conversion from 'Complex' to 'bool' for 1st argument
//       operator<<(bool __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:180:7: note: candidate function not viable: no known conversion from 'Complex' to 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:183:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:191:7: note: candidate function not viable: no known conversion from 'Complex' to 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:194:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:203:7: note: candidate function not viable: no known conversion from 'Complex' to 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:207:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
//       operator<<(short __n);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:183:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:191:7: note: candidate function not viable: no known conversion from 'Complex' to 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:194:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:203:7: note: candidate function not viable: no known conversion from 'Complex' to 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:207:7: note: candidate function not viable: no known conversion from 'Complex' to 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:222:7: note: candidate function not viable: no known conversion from 'Complex' to 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:226:7: note: candidate function not viable: no known conversion from 'Complex' to 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:234:7: note: candidate function not viable: no known conversion from 'Complex' to 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:297:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:330:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:564:5: note: candidate function template not viable: no known conversion from 'Complex' to 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:570:5: note: candidate function template not viable: no known conversion from 'Complex' to 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:581:5: note: candidate function template not viable: no known conversion from 'Complex' to 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:586:5: note: candidate function template not viable: no known conversion from 'Complex' to 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:662:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:675:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:680:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/ostream.tcc:307:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:81:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Resetiosflags' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Resetiosflags __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:111:5: note/opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:222:7: note: candidate function not viable: no known conversion from 'Complex' to 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:226:7: note: candidate function not viable: no known conversion from 'Complex' to 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:234:7: note: candidate function not viable: no known conversion from 'Complex' to 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:297:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:330:7: note: candidate function not viable: no known conversion from 'Complex' to 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:564:5: note: candidate function template not viable: no known conversion from 'Complex' to 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:570:5: note: candidate function template not viable: no known conversion from 'Complex' to 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:581:5: note: candidate function template not viable: no known conversion from 'Complex' to 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:586:5: note: candidate function template not viable: no known conversion from 'Complex' to 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:662:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:675:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:680:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/ostream.tcc:307:5: note: candidate function template not viable: no known conversion from 'Complex' to 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:81:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Resetiosflags' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Resetiosflags __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:111:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setiosflags' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setiosflags __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:145:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setbase' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setbase __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:210:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setprecision' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setprecision __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:240:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setw' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setw __f)
//     ^
// input_line_8:4:10:: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setiosflags' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setiosflags __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:145:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setbase' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setbase __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:210:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setprecision' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setprecision __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:240:5: note: candidate function template not viable: no known conversion from 'Complex' to 'std::_Setw' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setw __f)
//     ^
// input_line_8:4:10: note: candidate function not viable: no known conversion from 'Complex' to 'const Point' for 2nd argument
// ostream& operator<<(ostream& out, const Point& c);
//          ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:554:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'Complex')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
//  note: candidate function not viable: no known conversion from 'Complex' to 'const Point' for 2nd argument
// ostream& operator<<(ostream& out, const Point& c);
//          ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:554:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'Complex')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/string_view:760:5: note: candidate template ignored: could not match 'basic_string_view<type-parameter-0-0, type-parameter-0-1>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/basic_string.h:4020:5: note: /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/string_view:760:5: note: candidate template ignored: could not match 'basic_string_view<type-parameter-0-0, type-parameter-0-1>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/basic_string.h:4020:5: note: candidate template ignored: could not match 'basic_string<type-parameter-0-0, type-parameter-0-1, type-parameter-0-2>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/shared_ptr.h:70:5: note: candidate template ignored: could not match '__shared_ptr<type-parameter-0-2, _Lp>' against 'Complex'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:candidate template ignored: could not match 'basic_string<type-parameter-0-0, type-parameter-0-1, type-parameter-0-2>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/shared_ptr.h:70:5: note: candidate template ignored: could not match '__shared_ptr<type-parameter-0-2, _Lp>' against 'Complex'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1160:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1171:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray<type-parameter-0-0>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1182:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:645:5: note: candidate template ignored: could not match 'const _CharT *' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/type_traits:116:46: note: candidate template ignored: disabled by 'enable_if' [with _Ostream = std::basic_ostream<char> &, _Tp = Complex]
//     using __enable_if_t = typename enable_if<_Cond, _Tp>::type;
//                                              ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:180:5: note: candidate template ignored: could not match '_Setfill<type-parameter-0-0>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setfill<_CharT> __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:313:5: note: candidate template ignored: could not match '_Put_money<type-parameter-0-2>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Put_money<_MoneyT> __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:365:5: note: candidate template ignored: could not match '_Put_time<type-parameter-0-0>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Put_time<_CharT> __f)
//     ^
// input_line_8:33:51: error: function definition is not allowed here
// ostream& operator<<(ostream& out, const Point& c) {
//                                                   ^
// 413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1160:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1171:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1198:1: note: candidate template ignored: could not match 'valarray<type-parameter-0-0>' against 'Complex'
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/valarray:1182:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/ostream:645:5: note: candidate template ignored: could not match 'const _CharT *' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/type_traits:116:46: note: candidate template ignored: disabled by 'enable_if' [with _Ostream = std::basic_ostream<char> &, _Tp = Complex]
//     using __enable_if_t = typename enable_if<_Cond, _Tp>::type;
//                                              ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:180:5: note: candidate template ignored: could not match '_Setfill<type-parameter-0-0>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Setfill<_CharT> __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:313:5: note: candidate template ignored: could not match '_Put_money<type-parameter-0-2>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Put_money<_MoneyT> __f)
//     ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.2.0/include/c++/iomanip:365:5: note: candidate template ignored: could not match '_Put_time<type-parameter-0-0>' against 'Complex'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, _Put_time<_CharT> __f)
//     ^
// input_line_8:33:51: error: function definition is not allowed here
// ostream& operator<<(ostream& out, const Point& c) {
//                                                   ^
// Interpreter Error:

// %% [markdown]
// ## Exercise
//
// 1. Create two Complex objects
// 2. Use the Swap function to swap them as Point types
// 3. Print the swapped objects as both Point and Complex objects

// %%
#include <iostream>
using namespace std;

class Point;
ostream& operator<<(ostream& out, const Point& c);

template<typename T>
void Swap(T &a, T &b) { 
    T temp = a; 
    a = b; 
    b = temp; 
}

class Point {
public:
    int x, y;
    
    Point(int c1, int c2) : x(c1), y(c2) {}
    
    Point& operator=(Point rhs) {
        x = rhs.x; 
        y = rhs.y;
        return *this;
    }
};

class Complex : public Point {
private:
    int &real, &imag;
    
public:
    Complex(int r, int i) : Point(r, i), real(x), imag(y) {
        cout << "Forming Complex: " << *this;
    }
    
    void printComplex() const {
        cout << "Complex: real=" << real << " imag=" << imag << endl;
    }
};

ostream& operator<<(ostream& out, const Point& c) {
    out << "x:" << c.x << " y:" << c.y << "\n";
    return out;
}

Complex c1(15, 15), c2(100, 100);

cout << "\nBefore swap:" << endl;
cout << "c1 as Point: " << c1;
cout << "c2 as Point: " << c2;

Swap(c1, c2);

cout << "\nAfter swap:" << endl;
cout << "c1 as Point: " << c1;
cout << "c2 as Point: " << c2;

c1.printComplex();
c2.printComplex();

// %% [markdown]
// ## Key points
//
// - Complex inherits public members (x, y) from Point
// - References (real, imag) are bound to base class members
// - Swap works because Complex is-a Point
// - Inheritance enables code reuse and polymorphism
